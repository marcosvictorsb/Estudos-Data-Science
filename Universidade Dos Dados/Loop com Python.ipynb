# %%
students = ["Andre", "Bruna", "Carol", "Eduardo", "Marcela", "Pedro"]
for student in students:
    print(student)
# Out:
# Andre
# Bruna
# Carol
# Eduardo
# Marcela
# Pedro

# %%
ids = []
for student in students:
    student_id = 'A123_'+student
    ids.append(student_id)
ids
# Out:
# ['A123_Andre',
#  'A123_Bruna',
#  'A123_Carol',
#  'A123_Eduardo',
#  'A123_Marcela',
#  'A123_Pedro']

# %%
for x in reversed(students):
    print(x)
# Out:
# Pedro
# Marcela
# Eduardo
# Carol
# Bruna
# Andre

# %%
for student in students:
    if student[0] in ['A', 'B', 'C', 'D', 'E', 'F']:
        student_id = 'A1_'+student
    else:
        student_id = 'A2_'+student
    ids.append(student_id);
    
ids
# Out:
# ['A123_Andre',
#  'A123_Bruna',
#  'A123_Carol',
#  'A123_Eduardo',
#  'A123_Marcela',
#  'A123_Pedro',
#  'A1_Andre',
#  'A1_Bruna',
#  'A1_Carol',
#  'A1_Eduardo',
#  'A2_Marcela',
#  'A2_Pedro']

# %%
import pandas as pd
import numpy as np
housing = pd.read_csv('housing.csv')
housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
bairros_ricos = []
for i in range(len(housing)):
    if housing.loc[i, "median_income"] >= 8.3252:
       bairros_ricos = bairros_ricos+[housing.loc[i, "ocean_proximity"]]
       
bairros_ricos[:10]
# Out:
# ['NEAR BAY',
#  'NEAR BAY',
#  'NEAR BAY',
#  'NEAR BAY',
#  'NEAR BAY',
#  'NEAR BAY',
#  'NEAR BAY',
#  'NEAR BAY',
#  'NEAR BAY',
#  'NEAR BAY']

# %%
import seaborn as sns
import matplotlib.pyplot as ptl
from scipy import stats

numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
housing_numeric = housing.select_dtypes(include=numerics)

fig, axs = ptl.subplots(ncols=3, nrows=3, figsize=(20,10))
index=0
axs = axs.flatten()

for x,v in housing_numeric.items():
    sns.histplot(v, ax=axs[index], kde=True)
    index += 1
